# %%
from csdmpy.data.ssda903 import SSDA903TableType
from csdmpy.datacontainer import DemandModellingDataContainer
import csdmpy_fakedata as sample

# %% [markdown]
# # Datacontainer API
#
# At the core of the datafiles api is the ability to read, index and merge the data files.
#
# To initialse the system, pass in a DataStore

# %%
dc = DemandModellingDataContainer(sample.V1)

dc.first_year, dc.last_year
# Out:
# (2017, 2021)

# %% [markdown]
# We can then access the files directly using the year and table type

# %%
dc.get_table(dc.first_year, SSDA903TableType.EPISODES)
# Out:
#        CHILD       DECOM RNE  LS CIN PLACE PLACE_PROVIDER         DEC  REC  \
# 0     398768  09/04/2017   S  L3  N1    U4            PR1  31/10/2017   E7
# 1     296227  11/09/2017   S  C1  N2    U5            PR4  13/09/2017   X1
# 2     296227  13/09/2017   P  C1  N2    U4            PR1         NaN   X1
# 3     868699  11/01/2016   P  J3  N7    H5            PR4  06/04/2017  E14
# 4     640353  10/11/2017   S  C2  N2    U5            PR4         NaN   X1
# ...      ...         ...  ..  ..  ..   ...            ...         ...  ...
# 1455  820261  21/01/2018   P  L2  N1    A4            PR4         NaN  E12
# 1456  548319  03/01/2017   S  V4  N3    U4            PR4  27/07/2017   X1
# 1457  548319  27/07/2017   L  V2  N3    U4            PR4  01/08/2017   X1
# 1458  548319  01/08/2017   P  V2  N3    U2            PR1  30/09/2017   X1
# 1459  548319  30/09/2017   P  V2  N3    U2            PR1         NaN  E47
#
#      REASON_PLACE_CHANGE HOME_POST  PL_POST      URN
# ...

# %% [markdown]
# ## Combining the files
#
# A key part of the demand modelling is a unified, combined view of several years. To do this the Headers and Episodes needs to be combined to
# create a child-based view. This view can be fetched on a year-by-year basis.

# %%
dc.get_combined_year(dc.first_year)
# Out:
#        CHILD  SEX        DOB ETHNIC            UPN  MOTHER      MC_DOB  \
# 0     398768    2 1999-12-17   BCRB  B097131712320     1.0  21/11/2017
# 1     296227    2 2002-06-23   NOBT  R056024362409     NaN         NaN
# 2     296227    2 2002-06-23   NOBT  R056024362409     NaN         NaN
# 3     868699    2 1999-04-12   BOTH  X090802290579     NaN         NaN
# 4     640353    1 2004-02-19   REFU  Z053273524673     NaN         NaN
# ...      ...  ...        ...    ...            ...     ...         ...
# 1455  820261    2 2001-08-15   NOBT  O050327186695     NaN         NaN
# 1456  548319    1 2006-10-13   AOTH  T012348497871     NaN         NaN
# 1457  548319    1 2006-10-13   AOTH  T012348497871     NaN         NaN
# 1458  548319    1 2006-10-13   AOTH  T012348497871     NaN         NaN
# 1459  548319    1 2006-10-13   AOTH  T012348497871     NaN         NaN
#
#           DECOM RNE  LS CIN PLACE PLACE_PROVIDER        DEC  REC  \
# ...

# %% [markdown]
# Next these files are combined and de-duplicated so we end up with a single, multi-year view.

# %%
dc.get_combined_data()
# Out:
#       CHILD  SEX        DOB ETHNIC            UPN  MOTHER MC_DOB      DECOM  \
# 69       91    2 1999-10-19   MOTH  W064737016429     NaN    NaN 2016-09-01
# 360     290    2 2000-11-13   MWBC  S077270991828     NaN    NaN 2016-11-19
# 361     290    2 2000-11-13   MWBC  S077270991828     NaN    NaN 2018-10-01
# 507     519    1 2002-03-26   AOTH  Z083151961630     NaN    NaN 2017-03-09
# 508     519    1 2002-03-26   AOTH  Z083151961630     NaN    NaN 2017-09-14
# ..      ...  ...        ...    ...            ...     ...    ...        ...
# 820  994520    1 1999-12-18   ABAN  H007512766791     NaN    NaN 2015-10-24
# 75   994928    1 2005-02-01   WROM  G039321116055     NaN    NaN 2017-01-11
# 55   994928    1 2005-02-01   WROM  G039321116055     NaN    NaN 2020-06-17
# 56   994928    1 2005-02-01   WROM  G039321116055     NaN    NaN 2021-11-25
# 987  998328    1 2004-03-15   AIND  F032614785936     NaN    NaN 2016-06-05
#
# ...

# %% [markdown]
# # Enrichment
#
# Now we can look at adding the additional fields required for analysis

# %%
dc.get_enriched_view()
# Out:
#       CHILD  SEX        DOB ETHNIC            UPN  MOTHER MC_DOB      DECOM  \
# 69       91    2 1999-10-19   MOTH  W064737016429     NaN    NaN 2016-09-01
# 360     290    2 2000-11-13   MWBC  S077270991828     NaN    NaN 2016-11-19
# 361     290    2 2000-11-13   MWBC  S077270991828     NaN    NaN 2018-10-01
# 507     519    1 2002-03-26   AOTH  Z083151961630     NaN    NaN 2017-03-09
# 508     519    1 2002-03-26   AOTH  Z083151961630     NaN    NaN 2017-09-14
# ..      ...  ...        ...    ...            ...     ...    ...        ...
# 820  994520    1 1999-12-18   ABAN  H007512766791     NaN    NaN 2015-10-24
# 75   994928    1 2005-02-01   WROM  G039321116055     NaN    NaN 2017-01-11
# 55   994928    1 2005-02-01   WROM  G039321116055     NaN    NaN 2020-06-17
# 56   994928    1 2005-02-01   WROM  G039321116055     NaN    NaN 2021-11-25
# 987  998328    1 2004-03-15   AIND  F032614785936     NaN    NaN 2016-06-05
#
#     RNE  LS  ...      URN        age    end_age  \
# ...

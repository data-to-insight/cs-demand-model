# %%
import pandas as pd
from csdmpy.data.ssda903 import SSDA903TableType
from csdmpy.datacontainer import DemandModellingDataContainer
import csdmpy_fakedata as sample
import csdmpy.timeseries as ts
import csdmpy.populations as pop
import csdmpy.constants as C
import csdmpy.transitions as trans

# %%
dc = DemandModellingDataContainer(sample.V1)
df = dc.get_enriched_view()
df_place = df[['CHILD', 'DECOM', 'DEC', 'PLACE', 'placement_type_before', 'placement_type', 'placement_type_after']]
df_place[df_place.CHILD==119095]
# Out:
#        CHILD      DECOM        DEC PLACE          placement_type_before  \
# 420   119095 2014-02-26 2017-02-19    R1  PlacementCategory.NOT_IN_CARE
# 1029  119095 2017-02-19 2017-06-25    U4  PlacementCategory.RESIDENTIAL
# 1030  119095 2017-06-25 2018-01-23    R2       PlacementCategory.FOSTER
# 1031  119095 2018-01-23 2018-03-17    R2        PlacementCategory.OTHER
# 687   119095 2018-03-17 2018-04-17    U4        PlacementCategory.OTHER
# 421   119095 2019-07-22 2019-10-10    U4  PlacementCategory.NOT_IN_CARE
# 422   119095 2019-10-10 2019-10-31    U5       PlacementCategory.FOSTER
#
#                      placement_type           placement_type_after
# 420   PlacementCategory.RESIDENTIAL       PlacementCategory.FOSTER
# 1029       PlacementCategory.FOSTER        PlacementCategory.OTHER
# 1030        PlacementCategory.OTHER        PlacementCategory.OTHER
# 1031        PlacementCategory.OTHER       PlacementCategory.FOSTER
# 687        PlacementCategory.FOSTER  PlacementCategory.NOT_IN_CARE
# 421        PlacementCategory.FOSTER       PlacementCategory.FOSTER
# 422        PlacementCategory.FOSTER  PlacementCategory.NOT_IN_CARE
